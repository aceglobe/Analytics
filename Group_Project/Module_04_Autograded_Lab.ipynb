# %% [markdown]
# # Exploratory Data Analysis (EDA)
#
# **Instructions:**
# - Do not modify locked cells
# - Write code only where indicated
# - Run all cells before submission
# - Dataset: EDA_Customer_Behavior_Module_IV.csv

# %% [markdown]
# ## Question 1
# **Load the dataset and compute basic descriptive statistics**

# %%
# YOUR CODE HERE
import pandas as pd
df = pd.read_csv('EDA_Customer_Behavior_Module_IV.csv')
df.describe()

# %%
assert df.shape[0] >= 200

# %% [markdown]
# ## Question 2
# **Create a histogram for Purchase_Amount**

# %%
# YOUR CODE HERE
import matplotlib.pyplot as plt
df['Purchase_Amount'].hist()
plt.xlabel('Purchase Amount')
plt.ylabel('Frequency')
plt.show()

# %%
assert 'Purchase_Amount' in df.columns

# %% [markdown]
# ## Question 3
# **Compute the correlation matrix and identify the strongest correlation**

# %%
# YOUR CODE HERE
corr = df.corr(numeric_only=True)
corr

# %%
assert corr.shape[0] >= 3

# %% [markdown]
# ## Question 4
# **Scatterplot between Annual_Income and Spending_Score**

# %%
# YOUR CODE HERE
plt.scatter(df['Annual_Income'], df['Spending_Score'])
plt.xlabel('Annual Income')
plt.ylabel('Spending Score')
plt.show()

# %%
assert 'Annual_Income' in df.columns and 'Spending_Score' in df.columns
